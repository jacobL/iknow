# %%
import pymysql
import pandas as pd
import datetime
import numpy as np
import xlrd
Creator = "10013783" #蘇佳敏

# %%
# 20200312 Init
# step 1. 同步  qmd_stopword from qs_stopword 
import pymysql  
connQS = pymysql.connect( host = '10.55.52.98' , port=33060 , user = 'root' , passwd = "1234" , db = 'qs')

curQS = connQS.cursor()
curQS2 = connQS.cursor()

columnList = ''
varList = '' 
curQS.execute("SHOW COLUMNS FROM qs_stopword")
for r in curQS :
    columnList = columnList+'`'+r[0]+'`,'
    varList = varList+'%s,'
columnList = columnList[0:len(columnList)-1]
varList = varList[0:len(varList)-1]
curQS.execute("select count(1) from qs_stopword")
#print('qs_stopword 欄位數:',len(r),' , 來源QS 筆數:',curMQ.fetchone()[0],' , 目的QS 筆數:',curQS.fetchone()[0])
curQS.execute("delete from qmd_stopword")

curQS.execute("select "+columnList+" from qs_stopword")
for r in curQS :    
    curQS2.execute("insert into qmd_stopword("+columnList+")values("+varList+")",(r))
curQS2.execute("commit")
curQS.execute("select count(1) from qmd_stopword")
print('    完成 目的QMD 筆數:',curQS.fetchone()[0])
# Out:
#     完成 目的QMD 筆數: 68

# %%
# 20200312 Init
# step 2. 將 "Sheet標準題" 解析到 standand_question
connQS = pymysql.connect( host = '10.55.52.98' , port=33060 , user = 'root' , passwd = "1234" , db = 'qs')
curQMD = connQS.cursor()

# step 2.1 qmd_standand_question 
path = "D:/曾行慶交接/IKnow_QS/QMD__系統問答資料庫_V2_0312.xlsx" 
data = xlrd.open_workbook(path)
sheet_raw = data.sheet_by_name('標準題')
print("QMD__系統問答資料庫 row num:", sheet_raw.nrows,",col num:", sheet_raw.ncols)
curQMD.execute("delete from qmd_standand_question")
for row in range(1, sheet_raw.nrows):   
    Answer_NO = sheet_raw.cell(row,0).value
    System = sheet_raw.cell(row,1).value
    Question = sheet_raw.cell(row,2).value
    category_main = sheet_raw.cell(row,3).value
    category_sub = sheet_raw.cell(row,4).value
    Answer = sheet_raw.cell(row,5).value
    Keyword = sheet_raw.cell(row,6).value
    SOP_chapter = sheet_raw.cell(row,7).value
    SOP_No = sheet_raw.cell(row,8).value
    URL = sheet_raw.cell(row,9).value
    #Enabled = sheet_raw.cell(row,10).value
    Enabled = 'True'
    Creator = sheet_raw.cell(row,11).value
    Create_Date = sheet_raw.cell(row,12).value     
     
    curQMD.execute("insert into qmd_standand_question(Answer_NO,System,Question,category_main,category_sub,Answer,Keyword,\
    SOP_chapter,SOP_No,URL,Enabled,Creator,Create_Date)values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,CONVERT_TZ(NOW(),'+00:00','+8:00'))",\
    (Answer_NO,System,Question,category_main,category_sub,Answer,Keyword,SOP_chapter,SOP_No,URL,Enabled,Creator))
    curQMD.execute("commit")
# Out:
# QMD__系統問答資料庫 row num: 519 ,col num: 13

# %%
# 20200312 Init
# step 3. 將 "Sheet相似題" 解析到 sim_question
connQMD = pymysql.connect( host = '10.55.52.98' , port=33060 , user = 'root' , passwd = "1234" , db = 'qs')
curQMD = connQMD.cursor()
# step 3.1 qmd_sim_question
path = "D:/曾行慶交接/IKnow_QS/QMD__系統問答資料庫_V2_0312.xlsx" 
data = xlrd.open_workbook(path)
sheet_raw = data.sheet_by_name('相似題')
print("QMD各系統問答資料庫 相似題 row num:", sheet_raw.nrows,",col num:", sheet_raw.ncols) 
curQMD.execute("delete from qmd_sim_question")
for row in range(1, sheet_raw.nrows):
    Answer_NO = sheet_raw.cell(row,0).value
    Question = sheet_raw.cell(row,1).value
    print(row,' ',Answer_NO,' ',Question) 
    
    curQMD.execute("insert into qmd_sim_question(Answer_NO,Question,Creator,Create_Date)values(%s,%s,%s,CONVERT_TZ(NOW(),'+00:00','+8:00'))",\
    (Answer_NO,Question,Creator))
curQMD.execute("commit")
# Out:
# QMD各系統問答資料庫 相似題 row num: 2 ,col num: 2
# 1   QMD0001   什麼是總良率?
# 0

# %%
# 20200312 Init
# step 4. 將 "Sheet同義詞" 解析到 sim_question
connQS = pymysql.connect( host = '10.55.52.98' , port=33060 , user = 'root' , passwd = "1234" , db = 'qs')
curQS = connQS.cursor()
# step 4.1 qmd_sim_question
path = "D:/曾行慶交接/IKnow_QS/QMD__系統問答資料庫_V2_0312.xlsx" 
data = xlrd.open_workbook(path)
sheet_raw = data.sheet_by_name('同義詞')
print("QMD各系統問答資料庫 同義詞 row num:", sheet_raw.nrows,",col num:", sheet_raw.ncols) 
curQS.execute("delete from qmd_jieba_synon")
for row in range(1, sheet_raw.nrows):
    Word = sheet_raw.cell(row,2).value
    Synonymous = sheet_raw.cell(row,1).value
    print(row,' ',Word,' ',Synonymous) 
    
    curQS.execute("insert into qmd_jieba_synon(Word,Synonymous,Creator,Create_Date)values(%s,%s,%s,CONVERT_TZ(NOW(),'+00:00','+8:00'))",\
    (Word,Synonymous,Creator))
curQS.execute("commit")
# Out:
# QMD各系統問答資料庫 同義詞 row num: 2 ,col num: 3
# 1   總良率   Total Yield
# 0

# %%
# 20200312 Init
# step 5. 將 qs_standand_question裡的Keyword解析後，塞入qs_jiebadict
# step 5.1 QMD
import re 
connQS = pymysql.connect( host = '10.55.52.98' , port=33060 , user = 'root' , passwd = "1234" , db = 'qs')
curQS = connQS.cursor()
curQS2 = connQS.cursor()
# step 5.2 QMD
curQS.execute("delete from qmd_jiebadict")
curQS.execute("SELECT Keyword FROM qmd_standand_question")

for Key in curQS :
    KeywordList = re.split('，|；',Key[0])  
    for i in range(0,len(KeywordList)) :
        if len(KeywordList[i]) > 1 :
            curQS2.execute("insert ignore into qmd_jiebadict(jiebaword,Creator,Create_Date)values(%s,%s,CONVERT_TZ(NOW(),'+00:00','+8:00'))",(KeywordList[i],Creator))
curQS2.execute("commit")
# Out:
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'yield' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'km' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'dppm' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'qualification' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '510' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '90' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'engineering' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'return' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'abnormal' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'operation' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'altitude' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '高空' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '低壓' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'account' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'approval' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'maker' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'automotive' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'annual' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'action' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'quality' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'advanced' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'plan' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'receivable' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'and' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'analysis' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'resolution' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'process' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'list' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'supplier' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '原物料' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '名錄' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sheet' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'readiness' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'technology' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'development' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '產品設計人員' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'total' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'attenuated' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'reflectance' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'business' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'brightness' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'enhancement' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'film' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'backlight' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'components' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'blu' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'unit' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'biochemical' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'oxygen' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'demand' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'bill' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'materials' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'improvement' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'belt' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'review' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'of' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'corrective' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'preventive' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'report' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'customer' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'acceptance' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'specification' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cold' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cathode' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'fluorescent' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'lamp' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'tube' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '冷陰極螢光管' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'complaint' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'notice' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'chain' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'feedback' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'design' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ce' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'marking' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'conformité' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'européenne' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'change' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cell' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'gap' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'test' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'peeling' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'delivery' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'finish' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'kid' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'control' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'close' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'loop' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'management' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cod' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'chemical' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cof' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'chip' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'on' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'bend' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'bubble' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'oriented' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cost' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'poor' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cp' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'concept' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'platform' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'certified' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'service' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '客戶服務' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Test' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Run' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'Review' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'requirement' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'satisfaction' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'survey' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ct' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '測試站點' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'trade' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'partnership' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'against' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'terrorism' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'to' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'center' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'request' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'failure\xa0' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'mode' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'effects' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'six' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sigma' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'for' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '階段設計' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'history' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'the' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'time' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'do' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'it' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'right' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'first' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'define' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'measure' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'analyze' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'improve' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'device' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'record' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'dmso' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'dimethyl' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sulfoxide' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'order' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'built' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'evaluate' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '設計' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'dos' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'defects' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'per' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'million' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'opportunities' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'defect' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'parts' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'board' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'differencial' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'scanning' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'calorimetry' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ec' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'data' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'document' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'failure' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'industry' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'electronic' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '醫療器材' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'iso' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '14971' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'end' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'planning' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sample' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cycling' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'esd+temp' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'complex' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'actions' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'field' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'article' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'fda' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'food' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'drug' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'administration' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'front' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'in' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'out' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'strength' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'flicker' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'system' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'facility' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'monitoring' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'fourier' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'transform' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'infrared' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'spectrophotometer' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'gas' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'inspection' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'gm' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'gross' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'stress' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'gp' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'green' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'product' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'global' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'life' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'highly' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'accelerated' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'screen' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'heat' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'soak' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'high' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'performance' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'chromatography' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ht' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'is' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'temperature' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'start' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'humidity' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'storage' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'accreditation' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'bureau' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'international' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cover' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'icp' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ms' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'inductively' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'coupled' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'plasma' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'mass' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'spectrometer' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'rate' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'incoming' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'laboratory' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'cooperation' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'issue' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'engineer' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'assurance' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'initial' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'production' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'information' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'image' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sticking' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '影像殘留' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'standards' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '13485' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '14064' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '17025' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'iatf' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '16949' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'indium' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'oxide' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'creation' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'light' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'connector' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '12pin' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ffc' for key 'PRIMARY'")
#   result = self._query(query)
# ...
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'responsible' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'supporting' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'consulted' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'informed' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'repair' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'agreement' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'optimize' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'verify' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'revisit' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sales' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'rolling' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'bucket' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'forecast' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'electrical' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'rsd' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'room' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'rt' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'off' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'signal' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'noise' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'integration' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'semi' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'standard' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'procedure' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'division' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'statistical' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sqe' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'sourcing' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ship' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'stock' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'special' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'weakness' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'opportunity' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'threat' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 't&h' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '溫溼度循環' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '溫度循環' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'testing' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'check' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'tcon' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'thermal' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'tape' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'task' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '9000' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'methyl' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'tof' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'taiwan' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'occupational' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'safety' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'health' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'maintenance' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'technical' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'shock' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'upper' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'uv' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'vis' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'vender' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'association' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'verified' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'vendor' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'organic' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'warranty' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '不良品' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '退返率' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'wer' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'wip' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'work' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'weekly' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'working' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'ray' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'go' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'om' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'risk' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'social' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'code' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'conduct' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'pilot' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'run' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'afr' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'pm' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry '里程碑' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'objective' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'organization' for key 'PRIMARY'")
#   result = self._query(query)
# C:\Users\jacob.liang\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1062, "Duplicate entry 'with' for key 'PRIMARY'")
#   result = self._query(query)
# 0
